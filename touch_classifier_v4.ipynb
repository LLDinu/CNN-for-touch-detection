# %%
import math
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow as tf
from tensorflow.python.framework import ops
from cnn_utils import *
from cnn_functions_v5 import *

# %matplotlib inline
np.random.seed(1)

# %%
X_train, Y_train, X_test, Y_test = load_dataset_v4()

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 8656
# number of test examples = 2164
# X_train shape: (8656, 16, 32, 2)
# Y_train shape: (8656, 8, 16, 5)
# X_test shape: (2164, 16, 32, 2)
# Y_test shape: (2164, 8, 16, 5)

# %%
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 1.033359
#  1. Train set accuracy = 70.74
#  1. Train set error distance = 2.71965668863
#  2. Test set accuracy = 69.73
#  2. Test set error distance = 2.56957018217
# Cost after epoch 5: 0.253926
#  1. Train set accuracy = 94.74
#  1. Train set error distance = 1.27004002946
#  2. Test set accuracy = 94.5
#  2. Test set error distance = 1.14545316972
# Cost after epoch 10: 0.168409
#  1. Train set accuracy = 94.02
#  1. Train set error distance = 0.817813784476
#  2. Test set accuracy = 93.99
#  2. Test set error distance = 0.776431417888
# Cost after epoch 15: 0.143818
#  1. Train set accuracy = 92.41
#  1. Train set error distance = 0.471726731076
#  2. Test set accuracy = 93.16
#  2. Test set error distance = 0.449399789607
# Cost after epoch 20: 0.128356
#  1. Train set accuracy = 92.56
#  1. Train set error distance = 0.380605802808
#  2. Test set accuracy = 93.16
#  2. Test set error distance = 0.344572920818
# Cost after epoch 25: 0.117641
# ...

# %%
# Depthwise separable convolution (without ReLU) -> batch = 32, alpha = 0.001
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 107.508128
#  1. Train set accuracy = 11.33
#  1. Train set error distance = 1.19269373977
#  2. Test set accuracy = 12.25
#  2. Test set error distance = 1.16142960318
# Cost after epoch 5: 13.317602
# Cost after epoch 10: 10.413544
# Cost after epoch 15: 9.359583
# Cost after epoch 20: 8.694971
#  1. Train set accuracy = 87.2
#  1. Train set error distance = 0.288516190969
#  2. Test set accuracy = 88.22
#  2. Test set error distance = 0.279325699501
# Cost after epoch 25: 8.220889
# Cost after epoch 30: 7.950899
# Cost after epoch 35: 7.731313
# Cost after epoch 40: 7.432827
#  1. Train set accuracy = 90.91
#  1. Train set error distance = 0.252792219601
#  2. Test set accuracy = 92.05
#  2. Test set error distance = 0.242983945076
# Cost after epoch 45: 7.259275
# Cost after epoch 50: 7.076976
# Cost after epoch 55: 6.883866
# Cost after epoch 60: 6.733812
#  1. Train set accuracy = 92.31
#  1. Train set error distance = 0.254129160675
# ...

# %%
# Depthwise separable convolution with focal loss (w. sigmoid) : GAMMA SWEEP
print("\nGamma = 1")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 1, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 1.5")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 1.5, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 2")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 2, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 2.5")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 2.5, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 3")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 3, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 3.5")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 3.5, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 4")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 4, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 4.5")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 4.5, num_epochs = 100, minibatch_size = 32)
print("\nGamma = 5")
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 5, num_epochs = 100, minibatch_size = 32)
# Out:
# Gamma = 1
#  1. Train set precision = 0.9138
#  1. Train set recall = 0.9168
#  1. Train set error distance = 0.338325099637
#  2. Test set precision = 0.9149
#  2. Test set recall = 0.9113
#  2. Test set error distance = 0.339176607803
# Train Accuracy: 0.99481
# Test Accuracy: 0.994895
# Model saved in file: C:/Users/OneMoreCookie/Jupyter_notes/model_v4/model.ckpt
#
# Gamma = 1.5
#  1. Train set precision = 0.9187
#  1. Train set recall = 0.9314
#  1. Train set error distance = 0.300983046422
#  2. Test set precision = 0.9251
#  2. Test set recall = 0.9322
#  2. Test set error distance = 0.299477728371
# Train Accuracy: 0.995098
# Test Accuracy: 0.995191
# Model saved in file: C:/Users/OneMoreCookie/Jupyter_notes/model_v4/model.ckpt
#
# Gamma = 2
#  1. Train set precision = 0.9378
#  1. Train set recall = 0.9455
#  1. Train set error distance = 0.287058220406
#  2. Test set precision = 0.9319
#  2. Test set recall = 0.9347
#  2. Test set error distance = 0.284173285076
# ...

# %%
# Depthwise separable convolution -||- with gamma = 4.5 (new plot)
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 4.5, num_epochs = 101, minibatch_size = 32)
# Out:
# Cost after epoch 0: 152.043 (touch: 56.81%, coord: 16.45%, coord: 26.74%)
# Cost after epoch 5: 30.006 (touch: 46.32%, coord: 19.56%, coord: 34.12%)
# Cost after epoch 10: 21.529 (touch: 47.16%, coord: 14.53%, coord: 38.31%)
# Cost after epoch 15: 17.025 (touch: 51.93%, coord: 13.84%, coord: 34.23%)
# Cost after epoch 20: 13.592 (touch: 56.37%, coord: 14.80%, coord: 28.83%)
# Cost after epoch 25: 11.431 (touch: 60.46%, coord: 15.50%, coord: 24.04%)
# Cost after epoch 30: 10.211 (touch: 62.56%, coord: 16.06%, coord: 21.38%)
# Cost after epoch 35: 9.371 (touch: 63.70%, coord: 16.63%, coord: 19.66%)
# Cost after epoch 40: 8.780 (touch: 64.32%, coord: 17.00%, coord: 18.68%)
# Cost after epoch 45: 8.333 (touch: 64.62%, coord: 17.22%, coord: 18.16%)
# Cost after epoch 50: 7.978 (touch: 64.89%, coord: 17.43%, coord: 17.68%)
#  1. Train set precision = 0.9266
#  1. Train set recall = 0.9409
#  1. Train set error distance = 0.247878319411
#  2. Test set precision = 0.933
# ...

# %%
# Depthwise separable convolution -||- with gamma = 4.5
_ = model_v5(X_train, Y_train, X_test, Y_test, learning_rate = 0.0001, gamma = 4.5, num_epochs = 1000, minibatch_size = 32)
# Out:
# Cost after epoch 0: 144.343783
# Cost after epoch 5: 30.583494
# Cost after epoch 10: 21.658895
# Cost after epoch 15: 18.333234
# Cost after epoch 20: 15.815681
# Cost after epoch 25: 14.189843
# Cost after epoch 30: 12.931090
# Cost after epoch 35: 11.863817
# Cost after epoch 40: 10.948723
# Cost after epoch 45: 10.215046
# Cost after epoch 50: 9.605987
#  1. Train set precision = 0.9166
#  1. Train set recall = 0.9275
#  1. Train set error distance = 0.266762074856
#  2. Test set precision = 0.9235
#  2. Test set recall = 0.9305
#  2. Test set error distance = 0.26944345274
# Cost after epoch 55: 9.121903
# Cost after epoch 60: 8.724065
# Cost after epoch 65: 8.403423
# Cost after epoch 70: 8.117234
# Cost after epoch 75: 7.857536
#  1. Train set precision = 0.9193
#  1. Train set recall = 0.9399
#  1. Train set error distance = 0.257575496623
#  2. Test set precision = 0.927
#  2. Test set recall = 0.9436
#  2. Test set error distance = 0.25994505036
# ...

# %%
# Depthwise separable convolution (without ReLU) -> batch = 32, alpha = 0.0001, focal loss (0.5, 4, 0.8, 0.5) w. sigm. gamma = 3
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 298.791069
# Cost after epoch 5: 53.204443
# Cost after epoch 10: 36.531529
# Cost after epoch 15: 28.941920
# Cost after epoch 20: 24.850625
# Cost after epoch 25: 22.352840
# Cost after epoch 30: 20.596737
# Cost after epoch 35: 19.236337
# Cost after epoch 40: 18.131524
# Cost after epoch 45: 17.231895
# Cost after epoch 50: 16.482785
#  1. Train set precision = 0.92
#  1. Train set recall = 0.9349
#  1. Train set error distance = 0.299390812242
#  2. Test set precision = 0.9253
#  2. Test set recall = 0.9352
#  2. Test set error distance = 0.302398948669
# Cost after epoch 55: 15.840833
# Cost after epoch 60: 15.297165
# Cost after epoch 65: 14.855855
# Cost after epoch 70: 14.484941
# Cost after epoch 75: 14.172288
#  1. Train set precision = 0.9308
#  1. Train set recall = 0.946
#  1. Train set error distance = 0.269207812236
#  2. Test set precision = 0.937
#  2. Test set recall = 0.9494
#  2. Test set error distance = 0.268820500449
# ...

# %%
# Depthwise separable convolution (without ReLU) -> batch = 32, alpha = 0.0001, focal loss (0.5, 4, 0.8, 0.5) w. Sigmoid!
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 565.921015
# Cost after epoch 5: 88.485468
# Cost after epoch 10: 57.922068
# Cost after epoch 15: 47.651519
# Cost after epoch 20: 42.501566
# Cost after epoch 25: 38.868384
# Cost after epoch 30: 36.110896
# Cost after epoch 35: 33.847891
# Cost after epoch 40: 32.217366
# Cost after epoch 45: 30.932981
# Cost after epoch 50: 29.910257
#  1. Train set precision = 0.8964
#  1. Train set recall = 0.9037
#  1. Train set error distance = 0.331120402378
#  2. Test set precision = 0.9019
#  2. Test set recall = 0.9038
#  2. Test set error distance = 0.334334428698
# Cost after epoch 55: 29.073247
# Cost after epoch 60: 28.309228
# Cost after epoch 65: 27.652892
# Cost after epoch 70: 27.021428
# Cost after epoch 75: 26.445325
#  1. Train set precision = 0.9136
#  1. Train set recall = 0.9172
#  1. Train set error distance = 0.301868999045
#  2. Test set precision = 0.9201
#  2. Test set recall = 0.9199
#  2. Test set error distance = 0.302122479697
# ...

# %%
# Depthwise separable convolution (without ReLU) -> batch = 32, alpha = 0.0001, focal loss (0.5, 4, 0.4, 0.5) w. Sigmoid!
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 345.347997
# Cost after epoch 5: 63.032627
# Cost after epoch 10: 44.348035
# Cost after epoch 15: 37.125600
# Cost after epoch 20: 32.650052
# Cost after epoch 25: 29.411702
# Cost after epoch 30: 27.153184
# Cost after epoch 35: 25.438699
# Cost after epoch 40: 24.058343
# Cost after epoch 45: 23.000130
# Cost after epoch 50: 22.192619
#  1. Train set precision = 0.9045
#  1. Train set recall = 0.9294
#  1. Train set error distance = 0.303526323633
#  2. Test set precision = 0.9123
#  2. Test set recall = 0.9298
#  2. Test set error distance = 0.308810790463
# Cost after epoch 55: 21.544150
# Cost after epoch 60: 20.983371
# Cost after epoch 65: 20.515924
# Cost after epoch 70: 20.097985
# Cost after epoch 75: 19.728841
#  1. Train set precision = 0.906
#  1. Train set recall = 0.9353
#  1. Train set error distance = 0.294155421165
#  2. Test set precision = 0.9171
#  2. Test set recall = 0.9375
#  2. Test set error distance = 0.299681496389
# ...

# %%
# Depthwise separable convolution (without ReLU) -> batch = 32, alpha = 0.0001, focal loss (0.5, 4, 0.4, 0.5)
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 1327.091634
# Cost after epoch 5: 217.057127
# Cost after epoch 10: 96.606258
# Cost after epoch 15: 75.929137
# Cost after epoch 20: 66.632982
#  1. Train set precision = 0.1554
#  1. Train set recall = 0.3301
#  1. Train set error distance = 0.520267316668
#  2. Test set precision = 0.1629
#  2. Test set recall = 0.3433
#  2. Test set error distance = 0.521936696645
# Cost after epoch 25: 56.175175
# Cost after epoch 30: 47.999981
# Cost after epoch 35: 43.742160
# Cost after epoch 40: 41.032745
# Cost after epoch 45: 39.104085
#  1. Train set precision = 0.7878
#  1. Train set recall = 0.8253
#  1. Train set error distance = 0.434908880034
#  2. Test set precision = 0.7949
#  2. Test set recall = 0.83
#  2. Test set error distance = 0.439603458111
# Cost after epoch 50: 36.324026
# Cost after epoch 55: 34.709295
# Cost after epoch 60: 33.434171
# Cost after epoch 65: 32.577767
# Cost after epoch 70: 31.608775
#  1. Train set precision = 0.8791
# ...

# %%
# Depthwise separable convolution (without ReLU) -> batch = 32, alpha = 0.0002
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 214.772383
#  1. Train set precision = 0.0246
#  1. Train set recall = 0.1461
#  1. Train set error distance = 0.522825130159
#  2. Test set precision = 0.0263
#  2. Test set recall = 0.1531
#  2. Test set error distance = 0.525748745512
# Cost after epoch 5: 35.014648
# Cost after epoch 10: 26.458009
# Cost after epoch 15: 21.563936
# Cost after epoch 20: 17.937761
# Cost after epoch 25: 15.573380
#  1. Train set precision = 0.8266
#  1. Train set recall = 0.9031
#  1. Train set error distance = 0.309613599583
#  2. Test set precision = 0.8379
#  2. Test set recall = 0.9087
#  2. Test set error distance = 0.313887797531
# Cost after epoch 30: 14.069102
# Cost after epoch 35: 13.100233
# Cost after epoch 40: 12.326843
# Cost after epoch 45: 11.761620
# Cost after epoch 50: 11.263508
#  1. Train set precision = 0.8745
#  1. Train set recall = 0.9316
#  1. Train set error distance = 0.280182296985
#  2. Test set precision = 0.8845
#  2. Test set recall = 0.9319
# ...

# %%
# NEW cost function : (0.5, 4, 0.1, 0.5)
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 216.783317
#  1. Train set accuracy = 45.49
#  1. Train set error distance = 1.60037004138
#  2. Test set accuracy = 45.29
#  2. Test set error distance = 1.41948997345
# Cost after epoch 5: 37.361535
#  1. Train set accuracy = 86.68
#  1. Train set error distance = 0.33545088059
#  2. Test set accuracy = 87.62
#  2. Test set error distance = 0.320017584585
# Cost after epoch 10: 26.744346
#  1. Train set accuracy = 87.18
#  1. Train set error distance = 0.31306885598
#  2. Test set accuracy = 87.99
#  2. Test set error distance = 0.298709466291
# Cost after epoch 15: 22.851336
#  1. Train set accuracy = 88.46
#  1. Train set error distance = 0.300989903909
#  2. Test set accuracy = 89.19
#  2. Test set error distance = 0.281323512967
# Cost after epoch 20: 20.883263
#  1. Train set accuracy = 89.51
#  1. Train set error distance = 0.288746581628
#  2. Test set accuracy = 90.76
#  2. Test set error distance = 0.270704651978
# Cost after epoch 25: 19.519685
# ...

# %%
# Small CNN with NEW cost function : (0.5, 4, 0.1, 0.5)
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 693.585343
#  1. Train set accuracy = 39.19
#  1. Train set error distance = 14.5738310913
#  2. Test set accuracy = 39.19
#  2. Test set error distance = 15.0432471486
# Cost after epoch 5: 60.785590
#  1. Train set accuracy = 46.63
#  1. Train set error distance = 0.553393040054
#  2. Test set accuracy = 47.69
#  2. Test set error distance = 0.543610423848
# Cost after epoch 10: 42.677382
#  1. Train set accuracy = 75.18
#  1. Train set error distance = 0.344972647901
#  2. Test set accuracy = 75.09
#  2. Test set error distance = 0.32853801487
# Cost after epoch 15: 34.711416
#  1. Train set accuracy = 82.43
#  1. Train set error distance = 0.322380049389
#  2. Test set accuracy = 83.18
#  2. Test set error distance = 0.307194803391
# Cost after epoch 20: 28.332242
#  1. Train set accuracy = 85.65
#  1. Train set error distance = 0.313910340557
#  2. Test set accuracy = 86.74
#  2. Test set error distance = 0.303783093002
# Cost after epoch 25: 23.245334
# ...

# %%
# cost function : (1, 1, 40, 1)
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 1.182240
#  1. Train set accuracy = 72.52
#  1. Train set error distance = 4.08495097793
#  2. Test set accuracy = 71.53
#  2. Test set error distance = 3.86104971565
# Cost after epoch 5: 0.346541
#  1. Train set accuracy = 93.59
#  1. Train set error distance = 1.89122601033
#  2. Test set accuracy = 93.02
#  2. Test set error distance = 1.74501007634
# Cost after epoch 10: 0.279012
#  1. Train set accuracy = 94.79
#  1. Train set error distance = 1.67996624852
#  2. Test set accuracy = 94.96
#  2. Test set error distance = 1.48935197201
# Cost after epoch 15: 0.233580
#  1. Train set accuracy = 95.48
#  1. Train set error distance = 1.11829053244
#  2. Test set accuracy = 95.15
#  2. Test set error distance = 0.979854666972
# Cost after epoch 20: 0.200318
#  1. Train set accuracy = 95.79
#  1. Train set error distance = 0.760508270642
#  2. Test set accuracy = 95.52
#  2. Test set error distance = 0.699556284878
# Cost after epoch 25: 0.178860
# ...

# %%
# cost function : (1, 4, 10, 1)
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 1.997399
#  1. Train set accuracy = 42.56
#  1. Train set error distance = 2.8751447759
#  2. Test set accuracy = 42.65
#  2. Test set error distance = 2.76963129336
# Cost after epoch 5: 0.415144
#  1. Train set accuracy = 86.43
#  1. Train set error distance = 0.443343094277
#  2. Test set accuracy = 86.32
#  2. Test set error distance = 0.415804368002
# Cost after epoch 10: 0.299194
#  1. Train set accuracy = 87.58
#  1. Train set error distance = 0.333372140842
#  2. Test set accuracy = 88.4
#  2. Test set error distance = 0.315558423113
# Cost after epoch 15: 0.258236
#  1. Train set accuracy = 87.28
#  1. Train set error distance = 0.304811877681
#  2. Test set accuracy = 88.63
#  2. Test set error distance = 0.293671114072
# Cost after epoch 20: 0.236179
#  1. Train set accuracy = 87.92
#  1. Train set error distance = 0.295063284046
#  2. Test set accuracy = 89.23
#  2. Test set error distance = 0.283984192932
# Cost after epoch 25: 0.219993
# ...

# %%
# using huge network
parameters = model_v4(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 0.420627
#  1. Train set accuracy = 94.64
#  1. Train set error distance = 1.13933834961
#  2. Test set accuracy = 94.64
#  2. Test set error distance = 1.06013948617
# Cost after epoch 5: 0.090302
#  1. Train set accuracy = 98.27
#  1. Train set error distance = 0.22223447711
#  2. Test set accuracy = 98.29
#  2. Test set error distance = 0.214401218666
# Cost after epoch 10: 0.065811
#  1. Train set accuracy = 98.97
#  1. Train set error distance = 0.189081249829
#  2. Test set accuracy = 99.08
#  2. Test set error distance = 0.182971235949
# Cost after epoch 15: 0.053652
#  1. Train set accuracy = 99.24
#  1. Train set error distance = 0.178715908623
#  2. Test set accuracy = 99.21
#  2. Test set error distance = 0.170065649773
# Cost after epoch 20: 0.047618
#  1. Train set accuracy = 99.23
#  1. Train set error distance = 0.170609965228
#  2. Test set accuracy = 99.21
#  2. Test set error distance = 0.162751172136
# Cost after epoch 25: 0.040812
# ...

# %%
ops.reset_default_graph()                         # to be able to rerun the model without overwriting tf variables
tf.set_random_seed(1)                             # to keep results consistent (tensorflow seed)
seed = 3                                          # to keep results consistent (numpy seed)

# Create Placeholders of the correct shape
(m, n_H0, n_W0, n_C0) = X_train.shape 
(_, n_H1, n_W1, n_C1) = Y_train.shape
X = tf.placeholder(tf.float32, shape = (None, n_H0, n_W0, n_C0))
Y = tf.placeholder(tf.float32, shape = (None, n_H1, n_W1, n_C1))
    
# Initialize parameters
parameters = initialize_parameters_v4()

# Forward propagation: Build the forward propagation in the tensorflow graph
Z4 = forward_propagation_v4(X, parameters)

# Initialize all the variables globally
init = tf.global_variables_initializer()

# Create a saver object which will save all the variables
saver = tf.train.Saver()
model_path = "C:/Users/OneMoreCookie/Jupyter_notes/model_v4/model.ckpt"

# Start the session to compute the tensorflow graph
with tf.Session() as sess:

    # Run the initialization
    sess.run(init)

    # Load the trained parameters
    saver.restore(sess, model_path)
    
    var_list = sess.run(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES))
    var_array = np.array(var_list)
    print("W1: "+ str(var_array[0].shape))
    print("b1: "+ str(var_array[1].shape))
    print("W2: "+ str(var_array[2].shape))
    print("b1: "+ str(var_array[3].shape))
    print("W3: "+ str(var_array[4].shape))
    print("b2: "+ str(var_array[5].shape))
    print("W4: "+ str(var_array[6].shape))
    print("b4: "+ str(var_array[7].shape))
    
    h5f = h5py.File('weights_v4.h5', 'a')
    print(list(h5f.keys()))
    h5f.create_dataset('W1', data = var_array[0])
    h5f.create_dataset('b1', data = var_array[1])
    h5f.create_dataset('W2', data = var_array[2])
    h5f.create_dataset('b2', data = var_array[3])
    h5f.create_dataset('W3', data = var_array[4])
    h5f.create_dataset('b3', data = var_array[5])
    h5f.create_dataset('W4', data = var_array[6])
    h5f.create_dataset('b4', data = var_array[7])
    print(list(h5f.keys()))
    h5f.close()
# Out:
# INFO:tensorflow:Restoring parameters from C:/Users/OneMoreCookie/Jupyter_notes/model_v4/model.ckpt
# W1: (3, 3, 2, 8)
# b1: (1, 1, 1, 8)
# W2: (3, 3, 8, 8)
# b1: (1, 1, 1, 8)
# W3: (3, 3, 8, 16)
# b2: (1, 1, 1, 16)
# W4: (1, 1, 16, 5)
# b4: (1, 1, 1, 5)
# []
# ['W1', 'W2', 'W3', 'W4', 'b1', 'b2', 'b3', 'b4']

# %%
ops.reset_default_graph()                         # to be able to rerun the model without overwriting tf variables
tf.set_random_seed(1)                             # to keep results consistent (tensorflow seed)
seed = 3                                          # to keep results consistent (numpy seed)

# Create Placeholders of the correct shape
(m, n_H0, n_W0, n_C0) = X_train.shape 
(_, n_H1, n_W1, n_C1) = Y_train.shape
X = tf.placeholder(tf.float32, shape = (None, n_H0, n_W0, n_C0))
Y = tf.placeholder(tf.float32, shape = (None, n_H1, n_W1, n_C1))
    
# Initialize parameters
parameters = initialize_parameters_v4()

# Forward propagation: Build the forward propagation in the tensorflow graph
Z4 = forward_propagation_v4(X, parameters)

# Initialize all the variables globally
init = tf.global_variables_initializer()

# Create a saver object which will save all the variables
saver = tf.train.Saver()
model_path = "C:/Users/OneMoreCookie/Jupyter_notes/model_v4/model.ckpt"

# Start the session to compute the tensorflow graph
with tf.Session() as sess:

    # Run the initialization
    sess.run(init)

    # Load the trained parameters
    saver.restore(sess, model_path)
    
    var_list = sess.run(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES))
    var_array = np.array(var_list)
    print("W1: "+ str(var_array[0].shape))
    print("b1: "+ str(var_array[1].shape))
    print("W2a: "+ str(var_array[2].shape))
    print("b2a: "+ str(var_array[3].shape))
    print("W2b: "+ str(var_array[4].shape))
    print("b2b: "+ str(var_array[5].shape))
    print("W3a: "+ str(var_array[6].shape))
    print("b3a: "+ str(var_array[7].shape))
    print("W3b: "+ str(var_array[8].shape))
    print("b3b: "+ str(var_array[9].shape))
    print("W4: "+ str(var_array[10].shape))
    print("b4: "+ str(var_array[11].shape))
    
    h5f = h5py.File('weights_v4.h5', 'a')
    print(list(h5f.keys()))
    h5f.create_dataset('W1', data = var_array[0])
    h5f.create_dataset('b1', data = var_array[1])
    h5f.create_dataset('W2a', data = var_array[2])
    h5f.create_dataset('b2a', data = var_array[3])
    h5f.create_dataset('W2b', data = var_array[4])
    h5f.create_dataset('b2b', data = var_array[5])
    h5f.create_dataset('W3a', data = var_array[6])
    h5f.create_dataset('b3a', data = var_array[7])
    h5f.create_dataset('W3b', data = var_array[8])
    h5f.create_dataset('b3b', data = var_array[9])
    h5f.create_dataset('W4', data = var_array[10])
    h5f.create_dataset('b4', data = var_array[11])
    print(list(h5f.keys()))
    h5f.close()
# Out:
# INFO:tensorflow:Restoring parameters from C:/Users/OneMoreCookie/Jupyter_notes/model_v4/model.ckpt
# W1: (3, 3, 2, 8)
# b1: (1, 1, 1, 8)
# W2a: (3, 3, 8, 1)
# b2a: (1, 1, 1, 8)
# W2b: (1, 1, 8, 16)
# b2b: (1, 1, 1, 16)
# W3a: (3, 3, 16, 1)
# b3a: (1, 1, 1, 16)
# W3b: (1, 1, 16, 32)
# b3b: (1, 1, 1, 32)
# W4: (1, 1, 32, 5)
# b4: (1, 1, 1, 5)
# []
# ['W1', 'W2a', 'W2b', 'W3a', 'W3b', 'W4', 'b1', 'b2a', 'b2b', 'b3a', 'b3b', 'b4']

# %%
w = h5py.File('weights_v4.h5', 'r')
W1 = np.array(w['W1'][:])
W2 = np.array(w['W2'][:])
W3 = np.array(w['W3'][:])
print(W1[0,0,0])
print(W1.shape)
print(W2.shape)
print(W3.shape)
print(list(w.keys()))
w.close()

# %%
df_self = pd.read_excel("D:/Work/Touch data/touch_data_python_results/test_data.xlsx", sheetname="Self", header = None)
df_mut = pd.read_excel("D:/Work/Touch data/touch_data_python_results/test_data.xlsx", sheetname="Mutual", header = None)

self_data = df_self.as_matrix()
self_data = -self_data/1000.
self_data = np.reshape(self_data, (1, 16, 32))

mut_data = df_mut.as_matrix()
mut_data = -mut_data/1000.
mut_data = np.reshape(mut_data, (1, 16, 32))

data = np.stack([self_data, mut_data], axis = -1)

_ = run_model_v4(data)

# %%
print("Training set (%i data):" % X_train.shape[0])
_ = test_model_v5(X_train, Y_train)
print("\n\nTesting set (%i data):" % X_test.shape[0])
_ = test_model_v5(X_test, Y_test)
# Out:
# Training set (8656 data):
# Precision = 0.9779
# Recall = 0.98
# F1 score = 0.9789
# frames with FN only:
# [174, 411, 795, 836, 1082, 1128, 1288, 1423, 1718, 1978, 2087, 2438, 2811, 2970, 3203, 3256, 3298, 3909, 3918, 3930, 3984, 4090, 4183, 4291, 4714, 4786, 5091, 5098, 5366, 5852, 5853, 5883, 6258, 6396, 6456, 6531, 6558, 6620, 6771, 6869, 7184, 7386, 7558, 7806, 7904, 8095, 8214, 8350, 8432, 8443, 8463, 8492, 8549]
# frames with FP only:
# [17, 79, 95, 191, 214, 229, 371, 667, 767, 961, 1251, 1599, 1741, 1835, 1842, 1863, 1923, 2119, 2140, 2234, 2317, 2374, 2399, 2402, 2514, 2590, 2917, 3345, 3488, 3611, 3732, 4053, 4086, 4111, 4669, 4730, 4843, 4961, 5160, 5390, 5395, 5428, 5556, 5892, 5990, 6061, 6387, 6391, 6436, 6641, 6781, 6786, 6952, 6992, 6999, 7115, 7168, 7197, 7201, 7435, 7543, 7801, 7951, 8221, 8370, 8482, 8634]
# >100 frames with both FN and FP
# Mean error distance = 0.193192258364
#
#
# Testing set (2164 data):
# Precision = 0.9792
# Recall = 0.9826
# ...

# %%
# n = 1775
# _ = test_model_v3(X_train[n:n+1,:,:,0:2], Y_train[n:n+1,:,:,0:4])
# _ = run_model_v3(X_train[n:n+1,:,:,0:2])

n = 1655
_ = test_model_v5(X_test[n:n+1,:,:,0:2], Y_test[n:n+1,:,:,0:4])
_ = run_model_v5(X_test[n:n+1,:,:,0:2])
# Out:
# Identified touches :
# [[ 87.          81.        ]
#  [ 18.47934318  15.55365634]
#  [  1.73097128   0.82827067]]
# Labelled touches :
# [[ 100.          100.        ]
#  [  18.63697631   15.51933766]
#  [   1.87323457    0.75298248]]
# Mean error distance = 0.147539088203

# %%
_ = print_weights()

# %%
l = [0, 0, 0, 0, 0, 0, 0, 2, 0, 2, 0]
print(len(l))
print([i for i,val in enumerate(l) if val == 2])

# %%
print ("{:.2%}".format(0.21545))
print ("Cost after epoch i: f (touch: " + "{:.2%}".format(0.21545) + ", coord: " + "{:.2%}".format(0.56353) + ", coord: " + "{:.2%}".format(0.26353) + ")" )
# Out:
# 21.55%
# Cost after epoch i: f (touch: 21.55%, coord: 56.35%, coord: 26.35%)

# %%
a=np.reshape([1.3, 4, 2.5, 5], (math.floor(2.5),2))
print(a)
# Out:
# [[ 1.3  4. ]
#  [ 2.5  5. ]]

# %%
(a,b) = np.floor([2.5,2.2]).astype(int)
a=np.reshape([1.3, 4, 2.5, 5], (a,b))
print(a)
# Out:
# [[ 1.3  4. ]
#  [ 2.5  5. ]]
